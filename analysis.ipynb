# %%
file = open("my.log")

# %%
lines = file.readlines()

# %%
import re
pattern = "INFO:flwr:fit progress: \(([1-9]\d*), ([1-9]\d*\.\d*|0\.\d*[1-9]\d*), \{'accuracy': ([1-9]\d*\.\d*|0\.\d*[1-9]\d*)\}"
data = []
for line in lines:
    matchObj = re.match(pattern, line)
    if matchObj != None:
        data.append([int(matchObj.group(1)), 
                     float(matchObj.group(2)), 
                     float(matchObj.group(3))
                     ])

# %%
import pandas as pd

df = pd.DataFrame(data, columns=["round", "loss", "accuracy"])
df
# Out:
#      round      loss  accuracy
# 0        1  1.117899    0.4725
# 1        2  1.059395    0.4700
# 2        3  0.988855    0.5450
# 3        4  0.984098    0.5550
# 4        5  0.955318    0.5625
# ..     ...       ...       ...
# 995    996  0.687198    0.7100
# 996    997  0.687195    0.7100
# 997    998  0.687192    0.7100
# 998    999  0.687189    0.7100
# 999   1000  0.687186    0.7100
#
# [1000 rows x 3 columns]

# %%
df.plot(x="round", y="accuracy")
# Out:
# <AxesSubplot:xlabel='round'>

# %%
df.plot(x="round", y="loss")
# Out:
# <AxesSubplot:xlabel='round'>
